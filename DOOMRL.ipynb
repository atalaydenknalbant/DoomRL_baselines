# %% [markdown]
# # Reinforcement Learning on Doom(Vizdoom) with stable baselines3

# %% [markdown]
# ## Create GYM Environment and import libraries

# %%
# !pip install gym
# !pip install stable-baselines3[extra]
# !pip install vizdoom
import time
from vizdoom import *
import gym
from gym import Env
from gym.spaces import Discrete, Box
import numpy as np
import cv2
import os
import torch
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import BaseCallback
# Out:
# 'pip' is not recognized as an internal or external command,
# operable program or batch file.
# 'pip' is not recognized as an internal or external command,
# operable program or batch file.
# 'pip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
class doomGym(Env):
    def __init__(self, render=False, config='deadly_corridor1.cfg'):
        super().__init__()
        self.game = DoomGame()
        self.game.load_config(config)

        match render:
            case False:
                self.game.set_window_visible(False)
            case True:
                self.game.set_window_visible(True)

        self.game.init()

        self.observation_space = Box(low=0, high=255, shape=(100,160,1), dtype=np.uint8)
        self.action_space = Discrete(7)

        self.kc = 0.0
        self.ammo = 52.0
        self.health = 100.0

    def step(self, action):
        actions = np.identity(7)
        movement_reward = self.game.make_action(actions[action], 4)
        reward = 0.0

        if self.game.get_state():
            state = self.game.get_state().screen_buffer
            state = self.grayscale(state)
            game_variables = self.game.get_state().game_variables
            health, kc, ammo = game_variables
            health_delta = health - self.health
            self.health = health
            kc_delta = kc - self.kc
            self.kc = kc
            ammo_delta = ammo - self.ammo
            self.ammo = ammo
            health_delta = health_delta if health_delta<0.1 else 0.0
            kc_delta = kc_delta if kc_delta>0.1 else 0.0
            ammo_delta = ammo_delta if ammo_delta<0.1 else 0.0
            reward = movement_reward*2.25 + health_delta*20.0 + kc_delta*300.0  + ammo_delta*1.25
            info = ammo
        else:
            state = np.zeros(self.observation_space.shape)
            reward = 0.0
            info = 0.0


        info = {"info":info}
        done = self.game.is_episode_finished()

        return state, reward, done, info

    def render(self, mode="human"):
        pass

    def reset(self):
        self.game.new_episode()
        state = self.game.get_state().screen_buffer
        return self.grayscale(state)

    def grayscale(self, observation):
        gray = cv2.cvtColor(np.moveaxis(observation, 0, -1), cv2.COLOR_BGR2GRAY)
        resize = cv2.resize(gray, (160,100), interpolation=cv2.INTER_CUBIC)
        state = np.reshape(resize, (100,160,1))
        return state


    def close(self):
        self.game.close()

# %% [markdown]
# ## Create Callback

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
MODEL_DIR = './train/models'
LOG_DIR = './logs/'

# %%
callback = TrainAndLoggingCallback(check_freq=10000, save_path=MODEL_DIR)

# %% [markdown]
# ## Training

# %% [markdown]
# ### Set difficulty

# %%
d1 = 'deadly_corridor1.cfg'
d2 = 'deadly_corridor2.cfg'
d3 = 'deadly_corridor3.cfg'
d4 = 'deadly_corridor4.cfg'
d5 = 'deadly_corridor5.cfg'

# %% [markdown]
# ### Train Model

# %% [markdown]
# #### Load Pretrained Model

# %%
model = PPO.load('train/train_corridor/bm_d4_5.zip')

# %% [markdown]
# #### Create model(if you already loaded model pass this cell)

# %%
# env = doomGym(config=d1)
# model = PPO('CnnPolicy', env, tensorboard_log=LOG_DIR, verbose=1, learning_rate=0.00001, n_steps=8192, clip_range=0.1, gamma=0.95, gae_lambda=0.9)

# %% [markdown]
# #### Train Model

# %%
# env = doomGym(config=d1)
# model.set_env(env)
# model.learn(total_timesteps=200000, callback=callback)
# env.close()

# %%
# env = doomGym(config=d2)
# model.set_env(env)
# model.learn(total_timesteps=60000, callback=callback)
# env.close()

# %%
# env = doomGym(config=d3)
# model.set_env(env)
# model.learn(total_timesteps=60000, callback=callback)
# env.close()

# %%
# env = doomGym(config=d4)
# model.set_env(env)
# model.learn(total_timesteps=1000000, callback=callback)
# env.close()

# %% [markdown]
# Don't run cell below without saving your best d4 model. Model performs better on d5 if it is not trained on d5.

# %%
# env = doomGym(config=d5)
# model.set_env(env)
# model.learn(total_timesteps=500000, callback=callback)
# env.close()
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# Logging to ./logs/logs_corridor\PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 87.1     |
# |    ep_rew_mean     | 4.5e+03  |
# | time/              |          |
# |    fps             | 15       |
# |    iterations      | 1        |
# |    time_elapsed    | 519      |
# |    total_timesteps | 8192     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 86.9        |
# |    ep_rew_mean          | 4.43e+03    |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 2           |
# |    time_elapsed         | 1093        |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.007915325 |
# |    clip_fraction        | 0.0882      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.124      |
# |    explained_variance   | 0.401       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 2.71e+04    |
# |    n_updates            | 1610        |
# |    policy_gradient_loss | 0.00632     |
# |    value_loss           | 5.39e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 86.7        |
# |    ep_rew_mean          | 4.51e+03    |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 3           |
# |    time_elapsed         | 1606        |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.012687806 |
# |    clip_fraction        | 0.0957      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.123      |
# |    explained_variance   | 0.477       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 1.34e+04    |
# |    n_updates            | 1620        |
# |    policy_gradient_loss | 0.00628     |
# |    value_loss           | 5.66e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 86.2        |
# |    ep_rew_mean          | 4.55e+03    |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 4           |
# |    time_elapsed         | 2147        |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.011047769 |
# |    clip_fraction        | 0.0939      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.128      |
# |    explained_variance   | 0.404       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 4.74e+04    |
# |    n_updates            | 1630        |
# |    policy_gradient_loss | 0.00632     |
# |    value_loss           | 6.07e+04    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 85.8       |
# |    ep_rew_mean          | 4.79e+03   |
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 5          |
# |    time_elapsed         | 2637       |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.01747476 |
# |    clip_fraction        | 0.0992     |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -0.113     |
# |    explained_variance   | 0.363      |
# |    learning_rate        | 1e-05      |
# |    loss                 | 1.29e+04   |
# |    n_updates            | 1640       |
# |    policy_gradient_loss | 0.00796    |
# |    value_loss           | 5.66e+04   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 86.7        |
# |    ep_rew_mean          | 4.6e+03     |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 6           |
# |    time_elapsed         | 3037        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008215806 |
# |    clip_fraction        | 0.0933      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.109      |
# |    explained_variance   | 0.408       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 5.05e+04    |
# |    n_updates            | 1650        |
# |    policy_gradient_loss | 0.00624     |
# |    value_loss           | 5.82e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85.4        |
# |    ep_rew_mean          | 4.63e+03    |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 7           |
# |    time_elapsed         | 3439        |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.020638496 |
# |    clip_fraction        | 0.087       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.116      |
# |    explained_variance   | 0.33        |
# |    learning_rate        | 1e-05       |
# |    loss                 | 3.86e+04    |
# |    n_updates            | 1660        |
# |    policy_gradient_loss | 0.00716     |
# |    value_loss           | 6.07e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 87.2        |
# |    ep_rew_mean          | 4.51e+03    |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 8           |
# |    time_elapsed         | 3841        |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.011568559 |
# |    clip_fraction        | 0.0908      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.117      |
# |    explained_variance   | 0.434       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 3.33e+04    |
# |    n_updates            | 1670        |
# |    policy_gradient_loss | 0.00604     |
# |    value_loss           | 6.36e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85.5        |
# |    ep_rew_mean          | 4.46e+03    |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 9           |
# |    time_elapsed         | 4246        |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.017149227 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.125      |
# |    explained_variance   | 0.378       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 2.89e+04    |
# |    n_updates            | 1680        |
# |    policy_gradient_loss | 0.00713     |
# |    value_loss           | 5.21e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85.1        |
# |    ep_rew_mean          | 4.71e+03    |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 10          |
# |    time_elapsed         | 4647        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.012947284 |
# |    clip_fraction        | 0.0979      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.11       |
# |    explained_variance   | 0.44        |
# |    learning_rate        | 1e-05       |
# |    loss                 | 2.54e+04    |
# |    n_updates            | 1690        |
# |    policy_gradient_loss | 0.00828     |
# |    value_loss           | 5.96e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.8        |
# |    ep_rew_mean          | 4.64e+03    |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 11          |
# |    time_elapsed         | 5055        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.010379197 |
# |    clip_fraction        | 0.0911      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.109      |
# |    explained_variance   | 0.323       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 3.26e+04    |
# |    n_updates            | 1700        |
# |    policy_gradient_loss | 0.00637     |
# |    value_loss           | 6.43e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 86.2        |
# |    ep_rew_mean          | 4.79e+03    |
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 12          |
# |    time_elapsed         | 5442        |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.008964293 |
# |    clip_fraction        | 0.0868      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.112      |
# |    explained_variance   | 0.374       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 3.19e+04    |
# |    n_updates            | 1710        |
# |    policy_gradient_loss | 0.00503     |
# |    value_loss           | 6.13e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 86.3         |
# |    ep_rew_mean          | 4.66e+03     |
# | time/                   |              |
# |    fps                  | 18           |
# |    iterations           | 13           |
# |    time_elapsed         | 5811         |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0076751625 |
# |    clip_fraction        | 0.091        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.119       |
# |    explained_variance   | 0.378        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 2.47e+04     |
# |    n_updates            | 1720         |
# |    policy_gradient_loss | 0.00653      |
# |    value_loss           | 6.16e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 88          |
# |    ep_rew_mean          | 4.62e+03    |
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 14          |
# |    time_elapsed         | 6183        |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.010762622 |
# |    clip_fraction        | 0.0889      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.112      |
# |    explained_variance   | 0.365       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 2.95e+04    |
# |    n_updates            | 1730        |
# |    policy_gradient_loss | 0.00511     |
# |    value_loss           | 6.28e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 86.3        |
# |    ep_rew_mean          | 4.53e+03    |
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 15          |
# |    time_elapsed         | 6554        |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.015705679 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.118      |
# |    explained_variance   | 0.447       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 3.39e+04    |
# |    n_updates            | 1740        |
# |    policy_gradient_loss | 0.00796     |
# |    value_loss           | 5.64e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.3        |
# |    ep_rew_mean          | 4.33e+03    |
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 16          |
# |    time_elapsed         | 6924        |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.013400471 |
# |    clip_fraction        | 0.0963      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.106      |
# |    explained_variance   | 0.427       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 2.67e+04    |
# |    n_updates            | 1750        |
# |    policy_gradient_loss | 0.00796     |
# |    value_loss           | 6.47e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85.6        |
# |    ep_rew_mean          | 4.17e+03    |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 17          |
# |    time_elapsed         | 7299        |
# |    total_timesteps      | 139264      |
# | train/                  |             |
# |    approx_kl            | 0.013936073 |
# |    clip_fraction        | 0.0827      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.106      |
# |    explained_variance   | 0.411       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 4.15e+04    |
# |    n_updates            | 1760        |
# |    policy_gradient_loss | 0.00677     |
# |    value_loss           | 6.2e+04     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.8        |
# |    ep_rew_mean          | 4.61e+03    |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 18          |
# |    time_elapsed         | 7661        |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.012522474 |
# |    clip_fraction        | 0.09        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.104      |
# |    explained_variance   | 0.405       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 2.88e+04    |
# |    n_updates            | 1770        |
# |    policy_gradient_loss | 0.00608     |
# |    value_loss           | 5.78e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85.4        |
# |    ep_rew_mean          | 4.63e+03    |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 19          |
# |    time_elapsed         | 8025        |
# |    total_timesteps      | 155648      |
# | train/                  |             |
# |    approx_kl            | 0.010549694 |
# |    clip_fraction        | 0.0796      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.097      |
# |    explained_variance   | 0.334       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 3.28e+04    |
# |    n_updates            | 1780        |
# |    policy_gradient_loss | 0.00324     |
# |    value_loss           | 6.26e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85.3        |
# |    ep_rew_mean          | 4.43e+03    |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 20          |
# |    time_elapsed         | 8386        |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.011410454 |
# |    clip_fraction        | 0.0958      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.106      |
# |    explained_variance   | 0.313       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 2.33e+04    |
# |    n_updates            | 1790        |
# |    policy_gradient_loss | 0.00626     |
# |    value_loss           | 5.53e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85.5        |
# |    ep_rew_mean          | 4.91e+03    |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 21          |
# |    time_elapsed         | 8739        |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.013916274 |
# |    clip_fraction        | 0.0916      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.11       |
# |    explained_variance   | 0.378       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 2.8e+04     |
# |    n_updates            | 1800        |
# |    policy_gradient_loss | 0.00503     |
# |    value_loss           | 5.82e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.2        |
# |    ep_rew_mean          | 4.71e+03    |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 22          |
# |    time_elapsed         | 9094        |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.012583919 |
# |    clip_fraction        | 0.082       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.104      |
# |    explained_variance   | 0.241       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 2.1e+04     |
# |    n_updates            | 1810        |
# |    policy_gradient_loss | 0.0057      |
# |    value_loss           | 5.97e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 86          |
# |    ep_rew_mean          | 4.55e+03    |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 23          |
# |    time_elapsed         | 9455        |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.009589935 |
# |    clip_fraction        | 0.0791      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.0989     |
# |    explained_variance   | 0.343       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 2.19e+04    |
# |    n_updates            | 1820        |
# |    policy_gradient_loss | 0.00609     |
# |    value_loss           | 6.2e+04     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85.3        |
# |    ep_rew_mean          | 4.51e+03    |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 24          |
# |    time_elapsed         | 9818        |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.015171442 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.106      |
# |    explained_variance   | 0.301       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 2.31e+04    |
# |    n_updates            | 1830        |
# |    policy_gradient_loss | 0.00827     |
# |    value_loss           | 6.11e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 87.8        |
# |    ep_rew_mean          | 4.64e+03    |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 25          |
# |    time_elapsed         | 10170       |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.010186112 |
# |    clip_fraction        | 0.0939      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.11       |
# |    explained_variance   | 0.413       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 5.81e+04    |
# |    n_updates            | 1840        |
# |    policy_gradient_loss | 0.00662     |
# |    value_loss           | 6.5e+04     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 87        |
# |    ep_rew_mean          | 4.67e+03  |
# | time/                   |           |
# |    fps                  | 20        |
# |    iterations           | 26        |
# |    time_elapsed         | 10532     |
# |    total_timesteps      | 212992    |
# | train/                  |           |
# |    approx_kl            | 0.0161347 |
# |    clip_fraction        | 0.094     |
# |    clip_range           | 0.1       |
# |    entropy_loss         | -0.103    |
# |    explained_variance   | 0.443     |
# |    learning_rate        | 1e-05     |
# |    loss                 | 1.86e+04  |
# |    n_updates            | 1850      |
# |    policy_gradient_loss | 0.00669   |
# |    value_loss           | 6.04e+04  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 87.2        |
# |    ep_rew_mean          | 4.7e+03     |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 27          |
# |    time_elapsed         | 10894       |
# |    total_timesteps      | 221184      |
# | train/                  |             |
# |    approx_kl            | 0.012606388 |
# |    clip_fraction        | 0.0953      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.105      |
# |    explained_variance   | 0.306       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 2.76e+04    |
# |    n_updates            | 1860        |
# |    policy_gradient_loss | 0.00569     |
# |    value_loss           | 5.98e+04    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 86         |
# |    ep_rew_mean          | 4.68e+03   |
# | time/                   |            |
# |    fps                  | 20         |
# |    iterations           | 28         |
# |    time_elapsed         | 11255      |
# |    total_timesteps      | 229376     |
# | train/                  |            |
# |    approx_kl            | 0.00886193 |
# |    clip_fraction        | 0.0795     |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -0.0974    |
# |    explained_variance   | 0.397      |
# |    learning_rate        | 1e-05      |
# |    loss                 | 1.4e+04    |
# |    n_updates            | 1870       |
# |    policy_gradient_loss | 0.00457    |
# |    value_loss           | 5.87e+04   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85.9        |
# |    ep_rew_mean          | 4.57e+03    |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 29          |
# |    time_elapsed         | 11616       |
# |    total_timesteps      | 237568      |
# | train/                  |             |
# |    approx_kl            | 0.009098672 |
# |    clip_fraction        | 0.0923      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.0999     |
# |    explained_variance   | 0.399       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 3.32e+04    |
# |    n_updates            | 1880        |
# |    policy_gradient_loss | 0.00615     |
# |    value_loss           | 6.05e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 87.4         |
# |    ep_rew_mean          | 4.94e+03     |
# | time/                   |              |
# |    fps                  | 20           |
# |    iterations           | 30           |
# |    time_elapsed         | 11975        |
# |    total_timesteps      | 245760       |
# | train/                  |              |
# |    approx_kl            | 0.0049487324 |
# |    clip_fraction        | 0.0796       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.0958      |
# |    explained_variance   | 0.37         |
# |    learning_rate        | 1e-05        |
# |    loss                 | 1.55e+04     |
# |    n_updates            | 1890         |
# |    policy_gradient_loss | 0.00725      |
# |    value_loss           | 6.09e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 86          |
# |    ep_rew_mean          | 5.11e+03    |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 31          |
# |    time_elapsed         | 12329       |
# |    total_timesteps      | 253952      |
# | train/                  |             |
# |    approx_kl            | 0.012583237 |
# |    clip_fraction        | 0.0859      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.0958     |
# |    explained_variance   | 0.373       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 2.13e+04    |
# |    n_updates            | 1900        |
# |    policy_gradient_loss | 0.00497     |
# |    value_loss           | 5.98e+04    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 81.6       |
# |    ep_rew_mean          | 4.42e+03   |
# | time/                   |            |
# |    fps                  | 20         |
# |    iterations           | 32         |
# |    time_elapsed         | 12694      |
# |    total_timesteps      | 262144     |
# | train/                  |            |
# |    approx_kl            | 0.01542059 |
# |    clip_fraction        | 0.0753     |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -0.0919    |
# |    explained_variance   | 0.442      |
# |    learning_rate        | 1e-05      |
# |    loss                 | 1.95e+04   |
# |    n_updates            | 1910       |
# |    policy_gradient_loss | 0.004      |
# |    value_loss           | 5.54e+04   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85          |
# |    ep_rew_mean          | 5e+03       |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 33          |
# |    time_elapsed         | 13052       |
# |    total_timesteps      | 270336      |
# | train/                  |             |
# |    approx_kl            | 0.012995853 |
# |    clip_fraction        | 0.0803      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.0957     |
# |    explained_variance   | 0.423       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 1.78e+04    |
# |    n_updates            | 1920        |
# |    policy_gradient_loss | 0.00583     |
# |    value_loss           | 6.4e+04     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.5        |
# |    ep_rew_mean          | 4.7e+03     |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 34          |
# |    time_elapsed         | 13416       |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.011888806 |
# |    clip_fraction        | 0.0757      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.0853     |
# |    explained_variance   | 0.479       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 1.79e+04    |
# |    n_updates            | 1930        |
# |    policy_gradient_loss | 0.00716     |
# |    value_loss           | 5.49e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85.3        |
# |    ep_rew_mean          | 5.07e+03    |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 35          |
# |    time_elapsed         | 13782       |
# |    total_timesteps      | 286720      |
# | train/                  |             |
# |    approx_kl            | 0.013087702 |
# |    clip_fraction        | 0.0711      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.0847     |
# |    explained_variance   | 0.554       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 6.35e+04    |
# |    n_updates            | 1940        |
# |    policy_gradient_loss | 0.00543     |
# |    value_loss           | 5.81e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.4        |
# |    ep_rew_mean          | 5.07e+03    |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 36          |
# |    time_elapsed         | 14146       |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.010556162 |
# |    clip_fraction        | 0.0666      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.078      |
# |    explained_variance   | 0.569       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 1.48e+04    |
# |    n_updates            | 1950        |
# |    policy_gradient_loss | 0.00519     |
# |    value_loss           | 5.56e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 85.4         |
# |    ep_rew_mean          | 5.08e+03     |
# | time/                   |              |
# |    fps                  | 20           |
# |    iterations           | 37           |
# |    time_elapsed         | 14507        |
# |    total_timesteps      | 303104       |
# | train/                  |              |
# |    approx_kl            | 0.0069226422 |
# |    clip_fraction        | 0.0557       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.0684      |
# |    explained_variance   | 0.579        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 1.85e+04     |
# |    n_updates            | 1960         |
# |    policy_gradient_loss | 0.006        |
# |    value_loss           | 5.28e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.8        |
# |    ep_rew_mean          | 5.11e+03    |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 38          |
# |    time_elapsed         | 14871       |
# |    total_timesteps      | 311296      |
# | train/                  |             |
# |    approx_kl            | 0.008196449 |
# |    clip_fraction        | 0.0579      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.0713     |
# |    explained_variance   | 0.594       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 1.92e+04    |
# |    n_updates            | 1970        |
# |    policy_gradient_loss | 0.00371     |
# |    value_loss           | 5.03e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 83.7        |
# |    ep_rew_mean          | 5.06e+03    |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 39          |
# |    time_elapsed         | 15228       |
# |    total_timesteps      | 319488      |
# | train/                  |             |
# |    approx_kl            | 0.015096076 |
# |    clip_fraction        | 0.0585      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.0682     |
# |    explained_variance   | 0.592       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 3.01e+04    |
# |    n_updates            | 1980        |
# |    policy_gradient_loss | 0.00319     |
# |    value_loss           | 4.75e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 83.5         |
# |    ep_rew_mean          | 4.96e+03     |
# | time/                   |              |
# |    fps                  | 21           |
# |    iterations           | 40           |
# |    time_elapsed         | 15591        |
# |    total_timesteps      | 327680       |
# | train/                  |              |
# |    approx_kl            | 0.0120399045 |
# |    clip_fraction        | 0.0661       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.0661      |
# |    explained_variance   | 0.579        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 1.75e+04     |
# |    n_updates            | 1990         |
# |    policy_gradient_loss | 0.00851      |
# |    value_loss           | 5.46e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.3        |
# |    ep_rew_mean          | 4.4e+03     |
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 41          |
# |    time_elapsed         | 15957       |
# |    total_timesteps      | 335872      |
# | train/                  |             |
# |    approx_kl            | 0.010577006 |
# |    clip_fraction        | 0.0572      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.0699     |
# |    explained_variance   | 0.607       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 6.28e+04    |
# |    n_updates            | 2000        |
# |    policy_gradient_loss | 0.00385     |
# |    value_loss           | 5.5e+04     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 85.7       |
# |    ep_rew_mean          | 4.85e+03   |
# | time/                   |            |
# |    fps                  | 21         |
# |    iterations           | 42         |
# |    time_elapsed         | 16313      |
# |    total_timesteps      | 344064     |
# | train/                  |            |
# |    approx_kl            | 0.01341773 |
# |    clip_fraction        | 0.0717     |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -0.0772    |
# |    explained_variance   | 0.5        |
# |    learning_rate        | 1e-05      |
# |    loss                 | 2.89e+04   |
# |    n_updates            | 2010       |
# |    policy_gradient_loss | 0.0043     |
# |    value_loss           | 5.96e+04   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 86.1        |
# |    ep_rew_mean          | 5.18e+03    |
# | time/                   |             |
# |    fps                  | 21          |
# |    iterations           | 43          |
# |    time_elapsed         | 16677       |
# |    total_timesteps      | 352256      |
# | train/                  |             |
# |    approx_kl            | 0.006424643 |
# |    clip_fraction        | 0.0584      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.0651     |
# |    explained_variance   | 0.459       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 2.19e+04    |
# |    n_updates            | 2020        |
# |    policy_gradient_loss | 0.00467     |
# |    value_loss           | 5.74e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 83.1         |
# |    ep_rew_mean          | 4.85e+03     |
# | time/                   |              |
# |    fps                  | 21           |
# |    iterations           | 44           |
# |    time_elapsed         | 17157        |
# |    total_timesteps      | 360448       |
# | train/                  |              |
# |    approx_kl            | 0.0042442065 |
# |    clip_fraction        | 0.0551       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.0619      |
# |    explained_variance   | 0.561        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 3.17e+04     |
# |    n_updates            | 2030         |
# |    policy_gradient_loss | 0.00301      |
# |    value_loss           | 4.99e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 81.8        |
# |    ep_rew_mean          | 4.57e+03    |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 45          |
# |    time_elapsed         | 17656       |
# |    total_timesteps      | 368640      |
# | train/                  |             |
# |    approx_kl            | 0.011228254 |
# |    clip_fraction        | 0.0638      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.0659     |
# |    explained_variance   | 0.604       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 2.46e+04    |
# |    n_updates            | 2040        |
# |    policy_gradient_loss | 0.00601     |
# |    value_loss           | 5.25e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 82.3        |
# |    ep_rew_mean          | 4.96e+03    |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 46          |
# |    time_elapsed         | 18218       |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.007541892 |
# |    clip_fraction        | 0.0608      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.0683     |
# |    explained_variance   | 0.623       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 3.67e+04    |
# |    n_updates            | 2050        |
# |    policy_gradient_loss | 0.00337     |
# |    value_loss           | 5.82e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.2        |
# |    ep_rew_mean          | 5.13e+03    |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 47          |
# |    time_elapsed         | 18775       |
# |    total_timesteps      | 385024      |
# | train/                  |             |
# |    approx_kl            | 0.006794054 |
# |    clip_fraction        | 0.0601      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.06       |
# |    explained_variance   | 0.534       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 3.07e+04    |
# |    n_updates            | 2060        |
# |    policy_gradient_loss | 0.00732     |
# |    value_loss           | 5.45e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 83.5        |
# |    ep_rew_mean          | 4.79e+03    |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 48          |
# |    time_elapsed         | 19246       |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.006841083 |
# |    clip_fraction        | 0.0547      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.0531     |
# |    explained_variance   | 0.685       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 2.89e+04    |
# |    n_updates            | 2070        |
# |    policy_gradient_loss | 0.00348     |
# |    value_loss           | 4.76e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 83.5        |
# |    ep_rew_mean          | 5.3e+03     |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 49          |
# |    time_elapsed         | 19602       |
# |    total_timesteps      | 401408      |
# | train/                  |             |
# |    approx_kl            | 0.012451135 |
# |    clip_fraction        | 0.0499      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.0543     |
# |    explained_variance   | 0.584       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 1.36e+04    |
# |    n_updates            | 2080        |
# |    policy_gradient_loss | 0.00392     |
# |    value_loss           | 5.18e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 83.8        |
# |    ep_rew_mean          | 5.01e+03    |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 50          |
# |    time_elapsed         | 19983       |
# |    total_timesteps      | 409600      |
# | train/                  |             |
# |    approx_kl            | 0.007884404 |
# |    clip_fraction        | 0.0389      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.0421     |
# |    explained_variance   | 0.683       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 8.57e+03    |
# |    n_updates            | 2090        |
# |    policy_gradient_loss | 0.00302     |
# |    value_loss           | 4.24e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 86          |
# |    ep_rew_mean          | 4.97e+03    |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 51          |
# |    time_elapsed         | 20413       |
# |    total_timesteps      | 417792      |
# | train/                  |             |
# |    approx_kl            | 0.012025004 |
# |    clip_fraction        | 0.0436      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.0465     |
# |    explained_variance   | 0.76        |
# |    learning_rate        | 1e-05       |
# |    loss                 | 1.96e+04    |
# |    n_updates            | 2100        |
# |    policy_gradient_loss | 0.0045      |
# |    value_loss           | 3.97e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85.1        |
# |    ep_rew_mean          | 5.19e+03    |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 52          |
# |    time_elapsed         | 20948       |
# |    total_timesteps      | 425984      |
# | train/                  |             |
# |    approx_kl            | 0.009119996 |
# |    clip_fraction        | 0.049       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.0547     |
# |    explained_variance   | 0.706       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 2.87e+04    |
# |    n_updates            | 2110        |
# |    policy_gradient_loss | 0.003       |
# |    value_loss           | 4.94e+04    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 83.9       |
# |    ep_rew_mean          | 5.25e+03   |
# | time/                   |            |
# |    fps                  | 20         |
# |    iterations           | 53         |
# |    time_elapsed         | 21330      |
# |    total_timesteps      | 434176     |
# | train/                  |            |
# |    approx_kl            | 0.01071132 |
# |    clip_fraction        | 0.0465     |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -0.0497    |
# |    explained_variance   | 0.695      |
# |    learning_rate        | 1e-05      |
# |    loss                 | 2.5e+04    |
# |    n_updates            | 2120       |
# |    policy_gradient_loss | 0.00428    |
# |    value_loss           | 4.53e+04   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 84.7         |
# |    ep_rew_mean          | 5.29e+03     |
# | time/                   |              |
# |    fps                  | 20           |
# |    iterations           | 54           |
# |    time_elapsed         | 21677        |
# |    total_timesteps      | 442368       |
# | train/                  |              |
# |    approx_kl            | 0.0076644495 |
# |    clip_fraction        | 0.0397       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.044       |
# |    explained_variance   | 0.703        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 3.49e+04     |
# |    n_updates            | 2130         |
# |    policy_gradient_loss | 0.00318      |
# |    value_loss           | 4.16e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 85.1         |
# |    ep_rew_mean          | 5.45e+03     |
# | time/                   |              |
# |    fps                  | 20           |
# |    iterations           | 55           |
# |    time_elapsed         | 22021        |
# |    total_timesteps      | 450560       |
# | train/                  |              |
# |    approx_kl            | 0.0110200215 |
# |    clip_fraction        | 0.0781       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.0526      |
# |    explained_variance   | 0.691        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 1.02e+04     |
# |    n_updates            | 2140         |
# |    policy_gradient_loss | 0.0188       |
# |    value_loss           | 4.25e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 86.3        |
# |    ep_rew_mean          | 5.49e+03    |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 56          |
# |    time_elapsed         | 22366       |
# |    total_timesteps      | 458752      |
# | train/                  |             |
# |    approx_kl            | 0.008154724 |
# |    clip_fraction        | 0.0458      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.0418     |
# |    explained_variance   | 0.727       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 3.29e+04    |
# |    n_updates            | 2150        |
# |    policy_gradient_loss | 0.00462     |
# |    value_loss           | 3.7e+04     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85.2        |
# |    ep_rew_mean          | 5.08e+03    |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 57          |
# |    time_elapsed         | 22711       |
# |    total_timesteps      | 466944      |
# | train/                  |             |
# |    approx_kl            | 0.011448108 |
# |    clip_fraction        | 0.0443      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.0443     |
# |    explained_variance   | 0.64        |
# |    learning_rate        | 1e-05       |
# |    loss                 | 4.11e+04    |
# |    n_updates            | 2160        |
# |    policy_gradient_loss | 0.00412     |
# |    value_loss           | 4.46e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 84.6         |
# |    ep_rew_mean          | 5.08e+03     |
# | time/                   |              |
# |    fps                  | 20           |
# |    iterations           | 58           |
# |    time_elapsed         | 23057        |
# |    total_timesteps      | 475136       |
# | train/                  |              |
# |    approx_kl            | 0.0073688882 |
# |    clip_fraction        | 0.0483       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.0448      |
# |    explained_variance   | 0.691        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 3.33e+04     |
# |    n_updates            | 2170         |
# |    policy_gradient_loss | 0.00497      |
# |    value_loss           | 4.22e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 89.7        |
# |    ep_rew_mean          | 5.17e+03    |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 59          |
# |    time_elapsed         | 23406       |
# |    total_timesteps      | 483328      |
# | train/                  |             |
# |    approx_kl            | 0.008826958 |
# |    clip_fraction        | 0.0465      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.0418     |
# |    explained_variance   | 0.698       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 1.31e+04    |
# |    n_updates            | 2180        |
# |    policy_gradient_loss | 0.00464     |
# |    value_loss           | 4.77e+04    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 85.8       |
# |    ep_rew_mean          | 5.4e+03    |
# | time/                   |            |
# |    fps                  | 20         |
# |    iterations           | 60         |
# |    time_elapsed         | 23753      |
# |    total_timesteps      | 491520     |
# | train/                  |            |
# |    approx_kl            | 0.01644429 |
# |    clip_fraction        | 0.0572     |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -0.0534    |
# |    explained_variance   | 0.732      |
# |    learning_rate        | 1e-05      |
# |    loss                 | 2.1e+04    |
# |    n_updates            | 2190       |
# |    policy_gradient_loss | 0.00542    |
# |    value_loss           | 4.41e+04   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85.9        |
# |    ep_rew_mean          | 5.3e+03     |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 61          |
# |    time_elapsed         | 24186       |
# |    total_timesteps      | 499712      |
# | train/                  |             |
# |    approx_kl            | 0.012272814 |
# |    clip_fraction        | 0.05        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.0429     |
# |    explained_variance   | 0.646       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 1.88e+04    |
# |    n_updates            | 2200        |
# |    policy_gradient_loss | 0.00647     |
# |    value_loss           | 4.27e+04    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 88.6       |
# |    ep_rew_mean          | 5.09e+03   |
# | time/                   |            |
# |    fps                  | 20         |
# |    iterations           | 62         |
# |    time_elapsed         | 24738      |
# |    total_timesteps      | 507904     |
# | train/                  |            |
# |    approx_kl            | 0.01946668 |
# |    clip_fraction        | 0.0917     |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -0.0502    |
# |    explained_variance   | 0.745      |
# |    learning_rate        | 1e-05      |
# |    loss                 | 2.65e+04   |
# |    n_updates            | 2210       |
# |    policy_gradient_loss | 0.101      |
# |    value_loss           | 3.42e+04   |
# ----------------------------------------

# %% [markdown]
# ## Test Model

# %%
model = PPO.load('train/train_corridor/bm_d4_5.zip')

# %%
env = doomGym(render=True, config=d5)
env.reset()
# Out:
# array([[[32],
#         [33],
#         [25],
#         ...,
#         [27],
#         [23],
#         [24]],
#
#        [[27],
#         [33],
#         [23],
#         ...,
#         [24],
#         [24],
#         [24]],
#
#        [[20],
#         [35],
#         [23],
#         ...,
#         [24],
#         [24],
#         [24]],
#
#        ...,
#
#        [[75],
#         [63],
#         [62],
#         ...,
#         [44],
#         [71],
#         [60]],
#
#        [[15],
#         [48],
#         [47],
#         ...,
#         [49],
#         [69],
#         [47]],
#
#        [[22],
#         [14],
#         [26],
#         ...,
#         [57],
#         [37],
#         [39]]], dtype=uint8)

# %%
evaluate_policy(model, env, n_eval_episodes=20)
# Out:
# C:\Program Files\Python310\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 evaluate_policy(model, env, n_eval_episodes=20)
#
# File C:\Program Files\Python310\lib\site-packages\stable_baselines3\common\evaluation.py:86, in evaluate_policy(model, env, n_eval_episodes, deterministic, render, callback, reward_threshold, return_episode_rewards, warn)
#      84 while not done:
#      85     action, state = model.predict(obs, state=state, deterministic=deterministic)
# ---> 86     obs, reward, done, info = env.step(action)
#      87     episode_reward += reward
#      88     if callback is not None:
#
# Input In [2], in doomGym.step(self, action)
#      22 def step(self, action):
#      23     actions = np.identity(7)
# ---> 24     movement_reward = self.game.make_action(actions[action], 4)
#      25     reward = 0.0
#      27     if self.game.get_state():
#
# KeyboardInterrupt:
